# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore", category=UserWarning, message="Pandas requires version '1.3.6' or newer of 'bottleneck'")
# Out:
# /Users/joohalee/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
asian_countries = pd.read_csv("/Users/joohalee/Desktop/world-bank-wdi-analysis/data/asian_countries.csv")
asian_countries
# Out:
#           country  year  gdp_per_capita  employment_population_ratio  \
# 0     Afghanistan  2024             NaN                       32.511
# 1     Afghanistan  2023      379.707497                       32.402
# 2     Afghanistan  2022      377.665627                       32.333
# 3     Afghanistan  2021      408.625855                       36.022
# 4     Afghanistan  2020      527.834554                       36.710
# ...           ...   ...             ...                          ...
# 3310  Yemen, Rep.  1964             NaN                          NaN
# 3311  Yemen, Rep.  1963             NaN                          NaN
# 3312  Yemen, Rep.  1962             NaN                          NaN
# 3313  Yemen, Rep.  1961             NaN                          NaN
# 3314  Yemen, Rep.  1960             NaN                          NaN
#
#       gdp_growth  population_growth
# 0            NaN                NaN
# 1       2.710887           2.135594
# 2      -6.240172           1.435704
# 3     -20.738839           2.356098
# 4      -2.351101           3.153609
# ...          ...                ...
# 3310         NaN           2.289077
# 3311         NaN           2.205000
# 3312         NaN           2.220673
# 3313         NaN           2.197731
# 3314         NaN                NaN
#
# [3315 rows x 6 columns]

# %%
# Filter the DataFrame to include only the countries of interest
countries_of_interest = ["China", "Korea, Rep.", "Japan", "India"]
filtered_specific_df = asian_countries[asian_countries['country'].isin(countries_of_interest)]
print(filtered_specific_df.head())
# Out:
#     country  year  gdp_per_capita  employment_population_ratio  gdp_growth  \
# 520   China  2024             NaN                       62.404         NaN
# 521   China  2023    12175.196115                       62.756    5.249558
# 522   China  2022    11555.930238                       62.523    2.950670
# 523   China  2021    11223.255348                       64.056    8.448469
# 524   China  2020    10358.169997                       62.678    2.238638
#
#      population_growth
# 520                NaN
# 521          -0.103795
# 522          -0.013100
# 523           0.089252
# 524           0.238041

# %%
country_colors = {
    "China": "red",
    "Korea, Rep.": "blue",
    "Japan": "green",
    "India": "orange"
}

plt.figure(figsize=(14, 8))

plt.subplot(2, 1, 1)  
for country, color in country_colors.items():
    country_data = filtered_specific_df[filtered_specific_df['country'] == country]
    plt.plot(country_data['year'], country_data['population_growth'], label=country, color=color, linestyle='-', marker='o')

# Plot the data for population growth
plt.title('Population Growth Over Time for China, Korea, Japan, Taiwan, and India', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Population Growth (%)', fontsize=12)
plt.legend(title="Countries", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)

plt.subplot(2, 1, 2)  
for country, color in country_colors.items():
    country_data = filtered_specific_df[filtered_specific_df['country'] == country]
    plt.plot(country_data['year'], country_data['gdp_growth'], label=country, color=color, linestyle='--', marker='x')

# Plot the data for GDP growth
plt.title('GDP Growth Over Time for China, Korea, Japan, Taiwan, and India', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP Growth (%)', fontsize=12)
plt.legend(title="Countries", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Population Growth Over Time:
#
# The population growth trends for each country are now color-coded, making it easier to compare them. The red line represents China, which shows a gradual decline in population growth. India (orange) have relatively higher population growth, though with a decline over time. Japan (green) and Korea, Rep. (blue) show a significant decrease in population growth, particularly in recent decades.

# %% [markdown]
# GDP Growth Over Time:
#
# For GDP growth, each country is represented with a distinct color. China's GDP growth (red) shows more volatility, with a noticeable spike in the early 1990s. India (orange) and Taiwan (purple) exhibit positive growth in several periods, while Japan (green) and Korea (blue) show more fluctuations with occasional negative growth.

# %% [markdown]
# Conclusion:
# As countries exhibit grdual declines in population growth, it is important to note that GDP growth does not always correlate with population growth. For instance, China has experienced a decline in population growth but has maintained a relatively high GDP growth rate. Taiwan's GDP growth has been more stable compared to the other countries, despite its population growth decline. In contrast, Japan and Korea have seen both population and GDP growth decline over time. Also, China's dramatic increase population in 1960s, caused a great jump in GDP growth.
